# %%
import pandas as pd

# %%
data_tiroid_missing = pd.read_csv("data_tiroid_missing.csv", header = None)
data_tiroid_missing
# Out:
#        0     1    2     3     4  5
# 0    107  10.1  2.2   0.9   2.7  1
# 1    113   9.9  3.1     2   5.9  1
# 2    127  12.9  2.4   1.4   0.6  1
# 3    109   5.3  1.6   1.4   1.5  1
# 4    105   7.3  1.5   1.5  -0.1  1
# 5    105   6.1  2.1   1.4     7  1
# 6    110  10.4  1.6   1.6     ?  1
# 7    114   9.9  2.4   1.5   5.7  1
# 8    106   9.4  2.2   1.5     0  1
# 9      ?    13  1.1   0.9   3.1  1
# 10   106   4.2  1.2   1.6   1.4  1
# 11   110  11.3  2.3   0.9   3.3  1
# 12   116   9.2  2.7     1   4.2  1
# 13   112   8.1  1.9   3.7     2  1
# 14   122   9.7  1.6   0.9   2.2  1
# 15   109   8.4  2.1   1.1   3.6  1
# 16   111   8.4    ?   0.8   1.2  1
# 17   114   6.7  1.5     1   3.5  1
# 18   119  10.6  2.1   1.3   1.1  1
# 19   115   7.1  1.3   1.3     2  1
# 20   101   7.8  1.2     1   1.7  1
# 21   103  10.1  1.3   0.7   0.1  1
# 22   109  10.4  1.9   0.4  -0.1  1
# 23   102   7.6  1.8     2   2.5  1
# 24   121  10.1  1.7   1.3   0.1  1
# 25   100   6.1  2.4   1.8   3.8  1
# ...

# %%
import numpy as np
import matplotlib
data_tiroid_missing[[0,1,2,3,4]] = datatiroid_missing[[0,1,2,3,4]].replace('?', numpy.NaN)
print(data_tiroid_missing.head(214))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-40-3d72cee8b661> in <module>
#       1 import numpy as np
#       2 import matplotlib
# ----> 3 data_tiroid_missing[[0,1,2,3,4]] = datatiroid_missing[[0,1,2,3,4]].replace('?', numpy.NaN)
#       4 print(data_tiroid_missing.head(214))
#
# NameError: name 'datatiroid_missing' is not defined

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-1f0e51773440> in <module>
# ----> 1 data_tiroid_missing[[0,1,2,3,4]] = datatiroid_missing[[0,1,2,3,4]].replace("?", numpy.NaN)
#       2 print(data_tiroid_missing.head)
#
# NameError: name 'datatiroid_missing' is not defined
